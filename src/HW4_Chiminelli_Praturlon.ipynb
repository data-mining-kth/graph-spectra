# %% [markdown]
# # ID2222 Data Mining, Homework 4
# # **Graph Spectra**
#
# Brando Chiminelli, Tommaso Praturlon
#
# December 5th, 2022

# %% [markdown]
# ## Goal
# The goal of this notebook is to

# %% [markdown]
# ## How to run
#
# In order to run this notebook you need to import the datasets in a 'data/' directory. Then you can run all the notebook and read along the descriptions of the different parts of the implementation and check the comments present on the code.

# %% [markdown]
# ## Import libraries and read the dataset
# In the following we import the few libraries needed for the project and we read the dataset.

# %%
# %pip install networkx
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import networkx as nx

# %%
def load_graph(file: str, weight: bool = False) -> nx.Graph:
    """
    This function takes as input the path to a file containing a list of edges (and optionally weights)
    in a graph and outputs the graph in the form of a networkx class.
    :param file: the path to the file representing the graph
    :param weight: indicates if the file contains edge weights or not
    :return: a nx.Graph instance representing the graph
    """

    if weight:
        return nx.read_weighted_edgelist(
            path=file,
            delimiter=','
        )
    else:
        return nx.read_edgelist(
            path=file,
            delimiter=','
        )


if __name__ == '__main__':
    #G = load_graph('../data/example1.dat')
    G = load_graph('../data/example2.dat', weight=True)

    print('The size of the graph is {}.'.format(G.size()))

# %%
G = load_graph('../data/example1.dat')
nx.draw(G, node_size=20)
plt.show()

# %%
G = load_graph('../data/example2.dat', weight=True)
nx.draw(G, node_size=20)
plt.show()

# %% [markdown]
# # Implementation using Matlab
#
# Taking as reference (https://stackoverflow.com/questions/56416657/how-to-run-matlab-m-files-in-google-colab) for Matlab on Notebook.
#
# Implmenting the algorithm below.

# %%
password = "RiNgO"

# %%
# !sudo apt install octave
# Out:
# [sudo] password for ringo:
